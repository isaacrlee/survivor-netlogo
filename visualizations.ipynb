# %%
import csv
import pandas as pd
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
pd.read_csv("challenge-eliminated-list.csv")
# Out:
#    challenge-winner eliminated-contestant
# 0                 1        (contestant 8)
# 1                 1        (contestant 1)
# 2                 1        (contestant 9)
# 3                 1        (contestant 3)
# 4                 0       (contestant 18)
# 5                 0       (contestant 11)
# 6                 0       (contestant 12)
# 7                 0       (contestant 14)
# 8                 0       (contestant 19)
# 9                 0       (contestant 16)
# 10  (contestant 10)       (contestant 15)
# 11   (contestant 2)       (contestant 13)
# 12  (contestant 17)        (contestant 2)
# 13   (contestant 5)       (contestant 17)
# 14   (contestant 4)        (contestant 7)
# 15   (contestant 0)        (contestant 5)
# 16   (contestant 6)       (contestant 10)
# 17   (contestant 0)        (contestant 6)

# %%
pd.read_csv("contestant-resumes.csv")
# Out:
#     contestant  tribe  finish  individual-challenge-wins  mental  physical  \
# 0            8      0      20                          0       1         3
# 1            1      0      19                          0       1         3
# 2            9      0      18                          0       5         6
# 3            3      0      17                          0       6         7
# 4           18      1      16                          0       3         5
# 5           11      1      15                          0       4         5
# 6           12      1      14                          0       8         6
# 7           14      1      13                          0       4         3
# 8           19      1      12                          0       5         5
# 9           16      1      11                          0       4         5
# 10          15      1      10                          0       7         4
# ...

# %%
pd.read_csv("voting-histories.csv", index_col='contestant').fillna('')
# Out:
#            8 (8-2) 1 (5-4) 9 (4-4) 3 (4-3) 18 (7-3) 11 (7-2) 12 (7-1)  \
# contestant
# 4                8       1       9       3        -        -        -
# 0                8       1       9       3        -        -        -
# 6                8       1       9       3        -        -        -
# 10               -       -       -       -       18       11       12
# 5                8       4       4       4        -        -        -
# 7                8       4       4       4        -        -        -
# 17               -       -       -       -       18       11       12
# 2                8       1       9       3        -        -        -
# 13               -       -       -       -       18       11       12
# 15               -       -       -       -       18       11       12
# 16               -       -       -       -       18       11       12
# 19               -       -       -       -       18       11       12
# ...
